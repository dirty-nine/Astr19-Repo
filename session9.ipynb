# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# x = np.random.rand(1000) # 1000 numbers in range[0,1)
x = np.random.uniform(0, 1, 1000) # 1000 numbers in range [0,1]

# %%
plt.hist(x, bins = 100)
plt.xlabel('x axis')
plt.ylabel('y axis')

plt.show
plt.savefig('session9Graph.png')

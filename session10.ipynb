# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.lognormal(mean=0.0, sigma=0.0001, size=1000)

plt.hist(x, bins = 100)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.savefig('session10Graph.png')
